# %% [markdown]
# # Read a text file with pandas
#
# **Data**: upload `main.txt` when the first cell asks.
#
# Run the cells in order. <sub>Notebook generated from `src/mainn.py`</sub>

# %%
from pathlib import Path

files_needed = ["main.txt"]
missing = [f for f in files_needed if not Path(f).exists()]
if missing:
    try:
        from google.colab import files
        print("Upload:", ", ".join(missing))
        files.upload()   # select the file(s) in the picker
    except ImportError:
        print("Not running in Colab; place the dataset next to this notebook.")

# %%
from pathlib import Path
import pandas as pd
file_path = Path("main.txt")

# %%
df = pd.read_csv(file_path)
print(df.head())
