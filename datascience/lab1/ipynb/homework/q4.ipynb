# %% [markdown]
# # Q4 - Multiplication table
#
# Prints the 1-10 table of the number entered.
#
# Run the cell, then answer each prompt - press Enter to accept the default.
#
# <sub>Colab notebook generated from `homework/q4.py`</sub>

# %%
number = int(input("Enter a number (default 7): ").strip() or 7)

# %%
for i in range(1, 11):
    print(f"{number} x {i} = {number * i}")
